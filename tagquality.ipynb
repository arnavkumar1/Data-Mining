# %%
import csv
import pandas as pd

# %%
tags = pd.read_csv("tags.csv",sep=',')
tags = tags[tags.columns[:-1]]
tags2 = tags.groupby(['movieId', 'tag']).size().reset_index(name='relevance')
tags2.to_csv("./num-itemapps.csv")

rows = [] 
with open("num-itemapps.csv", 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for row in csvreader:
        rows.append(row)
tags2
# Out:
#       movieId                    tag  relevance
# 0           1                    fun          1
# 1           1                  pixar          2
# 2           2         Robin Williams          1
# 3           2                fantasy          1
# 4           2                   game          1
# 5           2       magic board game          1
# 6           3                  moldy          1
# 7           3                    old          1
# 8           5              pregnancy          1
# 9           5                 remake          1
# 10          7                 remake          1
# 11         11               politics          1
# 12         11              president          1
# 13         14               politics          1
# 14         14              president          1
# 15         16                  Mafia          1
# 16         17            Jane Austen          1
# 17         21              Hollywood          1
# 18         22          serial killer          1
# ...

# %%
l = len(rows)
for i in range(l):
    c = 0;
    for j in range(i+1,l):
            if(rows[i][1]==rows[j][1]):
                c=c + int(rows[i][3])
                print(c)
                print(rows[i][3])
    rows[i][3] = float(rows[i][3])
print(rows[0][3])
# Out:
# 0
# 0.5
# 0
# 0.25
# 0
# 0.25
# 0
# 0.25
# 0
# 0.25
# 0
# 0.25
# 0
# 0.25
# 0
# 0.5
# 0
# 0.5
# 0
# 0.5
# 0
# 0.5
# 0
# 0.5
# 0
# 0.5
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.125
# 0
# 0.3333333333333333
# 0
# 0.3333333333333333
# 0
# 0.3333333333333333
# 0
# 0.5
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# 0
# 0.14285714285714285
# ...

# %%
rows = [] 
with open("tags.csv", 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)
    for row in csvreader:
        rows.append(row)

for row in rows:
    del[row[-1]]
    row[-1] = row[-1].lower()

# %%
# Out:
# 60756 funny 1
# 60756 funny 2
# 60756 will ferrell 1
# 60756 will ferrell 2
# 1221 mafia 1
# 5995 holocaust 1
# 109487 sci-fi 1
# 109487 time-travel 1
# 3114 pixar 1
# 5388 atmospheric 1
# 8641 will ferrell 1
# 60756 funny 1
# 60756 funny 2
# 60756 will ferrell 1
# 60756 will ferrell 2
# 99114 soundtrack 1
# 122912 visually stunning 1
# 139385 visually appealing 1
# 260 classic 1
# 260 space action 1
# 260 sci-fi 1
# 260 sci-fi 2
# 260 epic 1
# 296 good dialogue 1
# 296 great soundtrack 1
# 296 non-linear 1
# 260 classic sci-fi 1
# 260 classic sci-fi 2
# 260 epic 1
# 260 classic 1
# 58301 dark humor 1
# 293 assassin 1
# 293 jean reno 1
# 2579 black and white 1
# 3793 superhero 1
# 4226 twist ending 1
# 4226 twist ending 2
# 4896 magic 1
# 5388 atmospheric 1
# 260 classic sci-fi 1
# 260 classic sci-fi 2
# 260 space action 1
# 4878 atmospheric 1
# 4878 dreamlike 1
# 4878 dreamlike 2
# 4878 hallucinatory 1
# 4878 hallucinatory 2
# 4878 psychological 1
# 4878 surreal 1
# ...

# %%
print(rows[0])
print("Total no. of rows: ", len(rows))
# Out:
# ['2', '60756', 'funny']
# Total no. of rows:  3683

# %%
distinct_tags = []
for row in rows:
    if row[-1] not in distinct_tags:
        distinct_tags.append(row[-1])

print(distinct_tags)
# Out:
# ['funny', 'highly quotable', 'will ferrell', 'boxing story', 'mma', 'tom hardy', 'drugs', 'leonardo dicaprio', 'martin scorsese', 'way too long', 'al pacino', 'gangster', 'mafia', 'holocaust', 'true story', 'twist ending', 'anthony hopkins', 'courtroom drama', 'britpop', 'indie record label', 'music', 'dumpster diving', 'sustainability', 'romantic comedy', 'wedding', 'painter', 'bloody', 'black hole', 'sci-fi', 'time-travel', 'fantasy', 'magic board game', 'robin williams', 'beautiful scenery', 'epic', 'historical', 'inspirational', 'medieval', 'mel gibson', 'oscar (best cinematography)', 'revenge', 'sword fight', 'black comedy', 'christina ricci', 'christopher lloyd', 'dark comedy', 'family', 'gothic', 'andy garcia', 'classic', 'francis ford coppola', 'quirky', 'macaulay culkin', 'sequel', 'animation', 'disney', 'original', 'pixar', 'tom hanks', 'ancient rome', 'history', 'imdb top 250', 'rome', 'russell crowe', 'ed harris', 'jude law', 'rachel weisz', 'sniper', 'world war ii', 'atm
# ...

# %%
api = []
at = []
moditem = []
for tag in distinct_tags:
    att = 0
    tparr = []
    for row in rows:
        if row[-1]==tag:
            att += 1
            if row[1] not in tparr:
                tparr.append(row[1])
            
    at.append(att)
    moditem.append(len(tparr))

# %%
print(len(at))
print(moditem[0])
# Out:
# 1475
# 22
